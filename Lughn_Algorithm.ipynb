# %% [markdown]
# Question (TR):
#
# Kredi kartlarını doğrulamak için luhn algoritması kullanılır. Buna göre kullanıcı tarafından girilen bir kredi kartı numarasının doğru olup olmadığını gösteren kodu yazınız.
# Luhn Algoritması:
#
# Öncelikle bir banka kartı numarasının 16 hanesini aralıklı olarak yazın. Önce ilk numaranın altını çizin. Sonra bir atlayarak diğer numaralar için de aynı şeyi yapın. Daha sonra tüm altını çizdiğiniz sayıları iki ile çarpın. Örneğin kart numaramız
# 4 4 3 7 1 2 1 4 5 6 1 8 9 1 7 3 olsun. İşaretlediğimiz sayıların iki katını aldığımızda
# 8 6 2 2 10 2 18 14 elde ederiz.
#
# Şimdi bütün sayıları toplayın. Bu esnada dikkat etmeniz gereken şey eğer sayınız iki basamaklı ise basamakları ayrı ayrı toplamalısınız. Yani 18 yerine 1+8 düşünmelisiniz. Bu durumda toplamımız 8+6+2+2+1+0+2+1+8+1+4+4+7+2+4+6+8+1+3= 70 biçiminde olacaktır. 70’in 10’a tam bölünebilmesi kartın geçerli olduğunu ve hata yapılmadığını gösterir. Hata yapsaydınız tam bölünmesi mümkün olmayacaktı.
#
# American Express kartlarının yalnızca 15 hanesi vardır. Bu durumda hesaplamamızı biraz değiştirmemiz gerekiyor. Kart numaramızda bu sefer ilk olarak soldan ikinci haneyi işaretleyeceğiz. Yine bir atlayarak işaretlemeye devam edeceğiz. Sürecin devamı aynı biçimde. Örneğin kart numaramız 3 7 8 2 8 2 2 4 6 3 1 0 0 0 5 biçiminde olsun.
#
# İşaretli rakamların toplamı: (1 + 4) + 4 + 4 + 8 + 6 + 0 + 0 = 27
# İşaretli olmayanların toplamı: 3 + 8 + 8 + 2 + 6 + 1 + 0 + 5 = 33.
#
# 2 sayı kümesinin toplamı 60’tır, yine 10 sayısının katıdır. Bu da bir kere daha hata yapmadığımızın göstergesidir. Son bir örnek daha verelim. Bu sefer ki örneğimiz de Diners Club kartını içersin. Bu kartlarda 14 hane bulunur ve 300 veya 305 ile başlar. Örneğin numaramız 3 0 5 6 9 3 0 9 0 2 5 9 0 4 olsun. 14 sayısı çift olduğu için 16 haneli kart ile yaptığımız tekniğin aynısını uygulayacağız. Baştan başlayarak bir atlamalı biçimde sayıları işaretledik. Şimdi bunların iki katını alacağız ve çıkan rakamların hepsini toplayacağız. Süreci takip ederseniz 50 sayısına ulaşırsınız ve bu da girdiğiniz kart numarasının doğru olduğunu gösterir.
#
# Yöntem:
# 1. Kullanıcıdan kredi kartı numarasını isteyin.
#
# 2. Eğer kradi kartı numarası 16 haneli ise visa/master; 15 haneli ise amerikan ekpress, kartı doğrulaması yapsın. Farklı bir numara girilirse hata versin.
#
# 3. Çıktı olarak program "Girdiğiniz kredi kartı geçerli bir Amerikan Express kartıdır" veya "Girdiğiniz kredi kartı geçersizdir" şeklinde bir çıktı üretsin.
#
# Author : Murat Uğur KİRAZ
#
# Luhn Algoritması ile ilgili daha fazla bilgi edinmek için:
# -https://tr.theastrologypage.com/luhn-formula#:~:text=Luhn%20form%C3%BCl%C3%BC%2C%20kredi%20kart%C4%B1%20numaralar%C4%B1,genellikle%20son%20basama%C4%9Fa%20g%C3%B6re%20do%C4%9Frular.
#
# #-----------------------------------------------------------------------------------------#
# Question (EN):
#
# Luhn hold is used to verify credit cards. Accordingly, enter the code that indicates whether a credit card number entered by the user is correct.
# Luhn's Algorithm:
#
# Usually type a debit card number 16 digits spaced. First draw the sky of the first number. Then do the same for the other numbers with a skip. Then multiply all the uses you've underlined by two. For example, our card number
# Let 4 4 3 7 1 2 1 4 5 6 1 8 9 1 7 3. Double the shields we marked in action.
# We get 8 6 2 2 10 2 18 14.
#
# Collect all the pieces now. In the meantime, what you need to pay attention to, if you say, is two-digit, you should collect the steps separately. So instead of 18 you should consider 1+8. Our sum in this case would be 8+6+2+2+1+0+2+1+8+1+4+4+7+2+4+6+8+1+3= 70 powers. The fact that 70 is exactly divisible by 10 indicates that the card is valid and no error has been made. It wouldn't have been entirely possible if you had made a mistake.
#
# American Express cards only have 15 digits. In this case, we need to slightly modify our calculation. In our card number, this time it will mark the second digit from the left first. Continue to continue each other by skipping again. The process continues in the same way. For example, let's say our card number is 3 7 8 2 8 2 2 4 6 3 1 0 0 0 5.
#
# Sum of marked findings: (1 + 4) + 4 + 4 + 8 + 6 + 0 + 0 = 27
# The unsigned sum: 3 + 8 + 8 + 2 + 6 + 1 + 0 + 5 = 33.
#
# The sum of 2 sets of numbers is 60, again a courtesy multiple of 10. This is an indication that we have not made a mistake once again. Let's give one last example. In our example this time, you include the Diners Club card. These cards have 14 digits and start with 300 or 305. For example, let's say our number is 3 0 5 6 9 3 0 9 0 2 5 9 0 4. Since the number 14 is even, we will apply the same technique that we produced with the 16-digit card. We've marked a corresponding jump format from the beginning. Now we're going to take double that and collect all the troops that come out. When you follow the process, you will reach 50, which shows that the card number you entered is correct.
#
# Method:
# 1. Ask the user for a credit card number.
#
# 2. Visa/master if the credit card number is 16 digits; If it is 15 digits, let american express verify the card. If a different number is entered, it will give an error.
#
# 3. As output, the program should output "The credit card you entered is a valid American Express card" or "The credit card you entered is invalid".
#
# Author : Murat Uğur KİRAZ
#
# You can get more information about Luhn Algorithm:
# -https://en.wikipedia.org/wiki/Luhn_algorithm

# %%
# Importing Libraries
import sys
import os
import time
import requests
import warnings
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup

# %%
# Configuration
warnings.simplefilter(action='ignore', category=UserWarning)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %%
# Getting card df from wikipedia:
r1 = requests.get('https://en.wikipedia.org/wiki/Payment_card_number')
soup = BeautifulSoup(r1.content, "lxml")
indiatable = soup.find("table", {"class": "wikitable mw-collapsible sortable"})
# print(indiatable)

# Creating Df from HTML (Actually I even didn't know there was a way to read table via HTML code)
df = pd.read_html(str(indiatable))


# Function for implementing the loading animation
def load_animation():
    # String to be displayed when the application is loading
    load_str = " made by tayfun dogruer >>>> importing data from wikipedia..."
    ls_len = len(load_str)

    # String for creating the rotating line
    animation = "|/-\\"
    anicount = 0

    # used to keep the track of
    # the duration of animation
    counttime = 0

    # pointer for travelling the loading string
    i = 0

    while counttime != 100:

        # used to change the animation speed
        # smaller the value, faster will be the animation
        time.sleep(0.075)

        # converting the string to list
        # as string is immutable
        load_str_list = list(load_str)

        # x->obtaining the ASCII code
        x = ord(load_str_list[i])

        # if the character is "." or " ", keep it unaltered
        # switch uppercase to lowercase and vice-versa
        if x != 32 and x != 46:
            if x > 90:
                y = x - 32
            else:
                y = x + 32
            load_str_list[i] = chr(y)

        # for storing the resultant string
        res = ''
        for j in range(ls_len):
            res = res + load_str_list[j]

        # displaying the resultant string
        sys.stdout.write("\r" + res + animation[anicount])
        sys.stdout.flush()

        # Assigning loading string
        # to the resultant string
        load_str = res

        anicount = (anicount + 1) % 4
        i = (i + 1) % ls_len
        counttime = counttime + 1

    # for windows OS
    if os.name == "nt":
        os.system("cls")

    # for linux / Mac OS
    else:
        os.system("clear")


load_animation()

# Convert list to dfframe
df = pd.DataFrame(df[0])

# Cleaning dfFrame
df = df[(df["Validation"] == "Luhn algorithm") & (df["Active"] == "Yes")]
df = df.drop(["Validation"], axis=1)
df = df.drop(["Active"], axis=1)

# Split the comma-separated IIN ranges and Length into separate rows
df = df.assign(**{'IIN ranges': df['IIN ranges'].str.split(',')})
df = df.explode('IIN ranges').reset_index(drop=True)
df = df.assign(**{'Length': df['Length'].str.split(',')})
df = df.explode('Length').reset_index(drop=True)

# Lenght and IIN ranges df Cleaning
df.loc[:, 'Length'] = df['Length'].str.replace(r'\[\d+\]', '', regex=True)
df.loc[:, 'Length'] = df['Length'].str.replace(r' ', '')
df.loc[:, 'IIN ranges'] = df['IIN ranges'].str.replace(r'\[\d+\]', '', regex=True)
df.loc[:, 'IIN ranges'] = df['IIN ranges'].str.replace(r'\(.*?\)', '', regex=True)
df.loc[:, 'IIN ranges'] = df['IIN ranges'].str.replace(r' ', '')

# Fixing ASCII Problem (It took me a long time to fix the problem........)
df.loc[:, 'Length'] = df['Length'].str.replace(r'–', '-', regex=True)
df.loc[:, 'IIN ranges'] = df['IIN ranges'].str.replace(r'–', '-', regex=True)
df = df.reset_index(drop=True)

print("\n")
print("Valid Card Combinations ('-' is between any number and 'IIN ranges' is first part of card number) : \n")
print(df)

# For menu loop
while True:
    print("_" * 100)
    print("This program shows whether the credit card is valid or not with the Luhn Algorithm\n".center(100), flush=True)
    print("Please enter your credit card number with a space in between:".center(100), flush=True)
    print("Sample Not Verified : (636 5686 9876 5234 1926) ".center(100), flush=True)
    print("Sample Verified : (636 5686 9876 5234 2926) ".center(100), flush=True)
    print("Press 0 to exit".center(100), flush=True)
    print("_" * 100)

    # Defiened a class for easier and better user data and also this make code flexable for future usage
    class Card:
        def __init__(self, number, data):
            self.number = number
            self.data = data
            self.number_ilk = self.number.split(" ")[0]
            self.number_ilk_len = len(self.number_ilk)
            self.card_name = ''
            self.list_number_int = []
            self.verified = "Not Verified !"

        # Which Bank Name ? Checking from wikipedia (Can be shortened)
        def card_type_classifier(self):
            try:
                # Iterreting through df rows for multiple columns conditions.
                """
                I made this for various card combinations. 
                For example: 1 1 (you can see from below code) meaning is ;
                both the 'IIN ranges' column and the 'Length' column have a '-' sign.
                so to fix this i used that chaotic code... Sorry Mr. Kiraz..
                """

                for index, row in self.data.iterrows():
                    if ("-" in row["Length"]) & ("-" in row["IIN ranges"]):  # 1 1
                        ilk_length = int(row["Length"].split("-")[0])
                        ikinci_length = int(row["Length"].split("-")[1])
                        aralik_length = np.arange(ilk_length, ikinci_length + 1, 1).tolist()
                        ilk_iin = int(row["IIN ranges"].split("-")[0])
                        ikinci_iin = int(row["IIN ranges"].split("-")[1])
                        aralik_iin = np.arange(ilk_iin, ikinci_iin + 1, 1).tolist()

                        if any(str(x) in str(self.number_ilk[:self.number_ilk_len + 1]) for x in aralik_iin) and (len(self.number.replace(" ", "")) in aralik_length):
                            self.card_name = row["Issuing network"]
                            return self.card_name
                        else:
                            continue
                    ##########################################
                    elif ("-" in row["IIN ranges"]) & ("-" not in row["Length"]):  # 1 0
                        ilk_iin = int(row["IIN ranges"].split("-")[0])
                        ikinci_iin = int(row["IIN ranges"].split("-")[1])
                        aralik_iin = np.arange(ilk_iin, ikinci_iin + 1, 1).tolist()
                        if any(str(x) in str(self.number_ilk[:self.number_ilk_len + 1]) for x in aralik_iin) and (len(self.number.replace(" ", "")) == int(row["Length"])):
                            self.card_name = row["Issuing network"]
                            return self.card_name
                        else:
                            continue
                    ##########################################
                    elif ("-" not in row["IIN ranges"]) & ("-" in row["Length"]):  # 0 1
                        ilk_length = int(row["Length"].split("-")[0])
                        ikinci_length = int(row["Length"].split("-")[1])
                        aralik_length = np.arange(ilk_length, ikinci_length + 1, 1).tolist()

                        if (str(row['IIN ranges']) in str(self.number_ilk[:self.number_ilk_len + 1])) and (len(self.number.replace(" ", "")) in aralik_length):

                            self.card_name = row["Issuing network"]
                            return self.card_name
                        else:
                            continue
                    ##########################################
                    elif ("-" not in row["IIN ranges"]) & ("-" not in row["Length"]):  # 0 0

                        if (str(row['IIN ranges']) in self.number_ilk[:self.number_ilk_len + 1]) and (len(self.number.replace(" ", "")) == int(row["Length"])):
                            self.card_name = row["Issuing network"]
                            return self.card_name

                        else:
                            continue
                ##########################################

            except IndexError:
                pass

        # Actually that's the real homework part
        def card_verifier(self):
            # Converting all numbers to integer then to list
            for i in list(self.number.replace(" ", "")):
                self.list_number_int.append(int(i))

            updated_list = []
            if len(self.number.replace(" ", "")) % 2 == 0:  # If its double card number
                for i in range(len(self.list_number_int)):

                    if i % 2 == 0:  # If its double index *2
                        updated_list.append(self.list_number_int[i] * 2)
                    else:
                        updated_list.append(self.list_number_int[i])
            else:
                for i in range(len(self.list_number_int)):  # If its single card number

                    if i % 2 == 1:  # If its single index *2
                        updated_list.append(self.list_number_int[i] * 2)
                    else:
                        updated_list.append(self.list_number_int[i])

            # Creating new list by looking wheather it's a double-digit number or not
            for i in updated_list:

                # If its double-digit: add first and second digit to the new list then del old one.
                if len(str(i)) > 1:
                    updated_list.append(int(str(i)[0]))
                    updated_list.append(int(str(i)[1]))
                    updated_list.remove(i)

                else:
                    continue

            # Toplayici variable is a collector. Collecting all list numbers via loop and checking for Verified
            toplayici = 0
            for i in updated_list:
                toplayici += int(i)
            if toplayici % 10 == 0:
                self.verified = "Verified !"
            else:
                pass
            return self.verified


    # Get input card number from user and adding exit code to break loop
    user_input = input("\n")
    if user_input == "0":
        sys.exit()
    user = Card(user_input, df)
    print("-" * 50)

    # Creating Random user from Database to make things more ornate:
    db_users = {"name": ["Ahmet", "Tayfun", "Mehmet", "Murat", "Serdar", "Hüseyin", "Hakan", "Cüneyt", "Berker", "Zeki", "Dursun", "Emin", "Fatma", "Havva", "Nur", "Serpil", "Burçin", "Güneş"],
                "surname": ["Balıkçı", "Doğruer", "Kiraz", "Yılmaz", "Yıldırım", "Batak", "Kılçıkçı", "Manolya", "Gürbüz", "Özetekin", "Özler", "Demin", "Elma", "Kırlangıç", "Gülür", "Hepcan", "Pehlivaner", "Anderson"],
                "ID": np.random.randint(low=10000000, high=100000000, size=18).tolist()}

    # Selecting random user
    random_index_name = np.random.randint(low=0, high=len(db_users["name"]))
    random_index_surname = np.random.randint(low=0, high=len(db_users["surname"]))
    random_user = {
        "name": db_users["name"][random_index_name],
        "surname": db_users["surname"][random_index_surname],
        "ID": db_users["ID"][random_index_name]
    }

    # Output
    if user.card_type_classifier() is not None:
        print(r"Validity of the card number : Verified User!")
        print(f"Validity of the Luhn Algorithm : ", user.card_verifier())
        print(f"Bank Name    :", user.card_type_classifier())
        print(f"Card Number  :", user_input)
        print(f"User Name    :", random_user['name'])
        print(f"User Surname :", random_user['surname'].upper())
        print(f"User ID      :", random_user['ID'])

    else:
        print("Wrong card number entered. This card is not registered in the system !")

    print("-" * 50)
# Out:
#  made by tayfun dogruer >>>> importing DATA FROM WIKIPEDIA...\
#
# Valid Card Combinations ('-' is between any number and 'IIN ranges' is first part of card number) :
#
#                                Issuing network         IIN ranges Length
# 0                             American Express                 34     15
# 1                             American Express                 37     15
# 2                                China T-Union                 31     19
# 3                               China UnionPay                 62  16-19
# 4                Diners Club International[10]                 36  14-19
# 5       Diners Club United States & Canada[11]                 54     16
# 6                                Discover Card               6011  16-19
# 7                                Discover Card            644-649  16-19
# 8                                Discover Card                 65  16-19
# 9                                Discover Card      622126-622925  16-19
# ...
